# %% [markdown]
# # 2 Google+

# %%
library(igraph)
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
Networks_info = dir("gplus")

# %% [markdown]
# ### Q18 How many personal networks are there?

# %%
print(sprintf("There are %s personal networks.",length(Networks_info)/6))
# Out:
# [1] "There are 132 personal networks."

# %% [markdown]
# ### Q19 The in-degree and out-degree distribution of the 3 certain personal networks

# %%
create_personal_network = function(nodeID) {
    edge_file = paste("gplus/", toString(nodeID), ".edges", sep="")
    g = read.graph(edge_file, format = "ncol", directed=TRUE)
    g = add_vertices(g, nv = 1, name = nodeID)
    # print (V(g)$name[vcount(g)])
    new_edges = c()
    for (node in 1:(vcount(g)-1)){
        new_edges = c(new_edges, c(vcount(g),node))
    }
    g = add_edges(g, new_edges)
    return(g)
}

# %%
g1 = create_personal_network("109327480479767108490")
g2 = create_personal_network("115625564993990145546")
g3 = create_personal_network("101373961279443806744")

# %%
plot_deg_dis = function(g){
    plot(degree.distribution(g,mode="out"))
    plot(degree.distribution(g,mode="in"))
}

# %%
plot_deg_dis(g1)
plot_deg_dis(g2)
plot_deg_dis(g3)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
